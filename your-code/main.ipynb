#
# [5 rows x 452 columns]

# %% [markdown]
# ### Step 2: Get the products purchased for a specific customer of your choice.

# %%
prod_purchase=customer_products['ProductName'][customer_products['CustomerID']==639].unique()
prod_purchase
#merging=cust_prod_pivot.T
#recomended_products = merging[merging[639]==0].nlargest(5,'Quantity')['Quantity']
#recomended_products
# Out:
# array(['Anchovy Paste - 56 G Tube', 'Appetizer - Mushroom Tart',
#        'Assorted Desserts', 'Bread - Italian Roll With Herbs',
#        'Bread - Raisin Walnut Oval', 'Bread - Rye',
#        'Cake - Cake Sheet Macaroon', 'Cheese - Brie, Triple Creme',
#        'Cheese - Cambozola', 'Cheese - Mix', 'Cheese - Mozzarella',
#        'Cheese - Wine', 'Chestnuts - Whole,canned',
#        'Chinese Foods - Chicken', 'Cinnamon Buns Sticky',
#        'Cookies Cereal Nut', 'Fenngreek Seed', 'Flavouring - Orange',
#        'Flour - Whole Wheat', 'Garlic', 'Garlic - Primerba, Paste',
#        'Halibut - Steaks', 'Ice Cream Bar - Hageen Daz To',
#        'Jolt Cola - Electric Blue', 'Juice - Apple Cider',
#        'Juice - V8 Splash', 'Ketchup - Tomato',
#        'Langers - Ruby Red Grapfruit', 'Liners - Banana, Paper',
#        'Milk - 2%', 'Napkin White - Starched', 'Ocean Spray - Ruby Red',
#        'Olive - Spread Tapenade', 'Oranges - Navel, 72',
#        'Oregano - Dry, Rubbed', 'Pastry - Choclate Baked',
#        'Peas - Pigeon, Dry', 'Pepper - Paprika, Hungarian', 'Pernod',
#        'Pomello', 'Pork - Hock And Feet Attached',
#        'Pork - Loin, Center Cut', 'Puree - Mocha', 'Salmon - Sockeye Raw',
#        'Sardines', 'Sauce - Gravy, Au Jus, Mix',
#        'Scallops - Live In Shell', 'Seedlings - Mix, Organic',
#        'Soupcontfoam16oz 116con', 'Sprouts - Baby Pea Tendrils',
#        'Squid - Tubes / Tenticles 10/20', 'Tea - English Breakfast',
#        'V8 - Berry Blend', 'Veal - Inside, Choice', 'Water, Tap',
#        'Wine - Magnotta - Belpaese', 'Wine - Toasted Head',
#        'Wine - Two Oceans Cabernet'], dtype=object)

# %% [markdown]
# ### Step 3: For each product the customer purchased, get a list of the top 5 similar products. Package the lists into a nested list, flatten the list, and then filter out any products the customer has already purchased.

# %%
sim=[]

for prod in prod_purchase:
    for elem  in distances[prod].sort_values(ascending=False)[0:5].index.to_list():
        sim.append(elem)
        
sim

for prod in prod_purchase:
    if prod in sim:
        sim.remove(prod)
sim
# Out:
# ['Bread - Hot Dog Buns',
#  'Yeast Dry - Fermipan',
#  'Water - Green Tea Refresher',
#  'Rice - Long Grain',
#  'Bread - Hot Dog Buns',
#  'Water - Green Tea Refresher',
#  'Cookie - Dough Variety',
#  'Sauce - Hollandaise',
#  'Spice - Peppercorn Melange',
#  'Water - Spring Water 500ml',
#  'Bread Fig And Almond',
#  'Onions - Vidalia',
#  'Flour - Teff',
#  'Water - Green Tea Refresher',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Water - Green Tea Refresher',
#  'Rabbit - Whole',
#  'Water - Green Tea Refresher',
#  'Scallops 60/80 Iqf',
#  'Garlic',
#  'Bread - Hot Dog Buns',
#  'Water - Green Tea Refresher',
#  'Bread - Hot Dog Buns',
#  'Cheese - Cambozola',
#  'Spice - Peppercorn Melange',
#  'Sauce - Hollandaise',
#  'Remy Red',
#  'Steam Pan - Half Size Deep',
#  'Bread - Hot Dog Buns',
#  'Cheese - Cambozola',
#  'Gatorade - Xfactor Berry',
#  'Water - Green Tea Refresher',
#  'Cream Of Tartar',
#  'Cheese - Mix',
#  'Cheese - Cambozola',
#  'Sauce - Hollandaise',
#  'Scallops 60/80 Iqf',
#  'Spice - Peppercorn Melange',
#  'Scallops 60/80 Iqf',
#  'Water - Green Tea Refresher',
#  'Rabbit - Whole',
#  'Gatorade - Xfactor Berry',
#  'Sauce - Rosee',
#  'Wine - Alsace Gewurztraminer',
#  'Pork - Loin, Center Cut',
#  'Table Cloth 120 Round White',
#  'Vol Au Vents',
#  'Smoked Paprika',
#  'Water - Green Tea Refresher',
#  'Cheese - Cambozola',
#  'Water - Green Tea Refresher',
#  'Sauce - Hollandaise',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Rice - Long Grain',
#  'Rabbit - Whole',
#  'Arizona - Green Tea',
#  'Bread - Hot Dog Buns',
#  'Vol Au Vents',
#  'Water - Green Tea Refresher',
#  'Steam Pan - Half Size Deep',
#  'Table Cloth 120 Round White',
#  'Orange - Canned, Mandarin',
#  'Water - Green Tea Refresher',
#  'Appetizer - Mushroom Tart',
#  'Bread - Roll, Soft White Round',
#  'Pork - Inside',
#  'Water - Spring Water 500ml',
#  'Water - Green Tea Refresher',
#  'Spice - Peppercorn Melange',
#  'Cheese - Cambozola',
#  'Steam Pan - Half Size Deep',
#  'Cheese - Cambozola',
#  'Bread - Hot Dog Buns',
#  'Water - Green Tea Refresher',
#  'Garlic',
#  'Water - Green Tea Refresher',
#  'Hinge W Undercut',
#  'Cheese - Cambozola',
#  'Sauce - Hollandaise',
#  'Rabbit - Whole',
#  'Cheese - Cambozola',
#  'Vol Au Vents',
#  'Bread - Hot Dog Buns',
#  'Garlic',
#  'Bread Crumbs - Japanese Style',
#  'Milk Powder',
#  'Nut - Chestnuts, Whole',
#  'Bread - Hot Dog Buns',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Cookies Cereal Nut',
#  'Bread - Hot Dog Buns',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Bread - Bistro White',
#  'Spice - Peppercorn Melange',
#  'Cookies Cereal Nut',
#  'Bread - Roll, Soft White Round',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Beans - Kidney, Red Dry',
#  'Soup - Canadian Pea, Dry Mix',
#  'Sauce - Hollandaise',
#  'Milk Powder',
#  'Pork - Loin, Center Cut',
#  'Pasta - Cheese / Spinach Bauletti',
#  'Soupfoamcont12oz 112con',
#  'Pork - Loin, Center Cut',
#  'Rabbit - Whole',
#  'Cheese - Cambozola',
#  'Spice - Peppercorn Melange',
#  'Water - Green Tea Refresher',
#  'Rice - Long Grain',
#  'Sauce - Rosee',
#  'Steam Pan - Half Size Deep',
#  'Water - Spring Water 500ml',
#  'Water - Green Tea Refresher',
#  'Spice - Peppercorn Melange',
#  'Milk Powder',
#  'Pasta - Detalini, White, Fresh',
#  'Sauce - Hollandaise',
#  'Raspberries - Fresh',
#  'Pie Filling - Cherry',
#  'Water - Green Tea Refresher',
#  'Beer - Blue',
#  'Bread - Hot Dog Buns',
#  'Pork - Loin, Center Cut',
#  'Water - Green Tea Refresher',
#  'Water - Green Tea Refresher',
#  'Beef Ground Medium',
#  'Remy Red',
#  'Phyllo Dough',
#  'Water - Green Tea Refresher',
#  'Sauce - Hollandaise',
#  'Sauce - Rosee',
#  'Water - Spring Water 500ml',
#  'Spice - Peppercorn Melange',
#  'Sauce - Hollandaise',
#  'Scallops 60/80 Iqf',
#  'Remy Red',
#  'Carbonated Water - Cherry',
#  'Beef - Prime Rib Aaa',
#  'Soup - Campbells, Beef Barley',
#  'Wine - Alsace Gewurztraminer',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Pork - Bacon, Double Smoked',
#  'Water - Green Tea Refresher',
#  'Cheese - Cambozola',
#  'Cheese - Cambozola',
#  'Sauce - Hollandaise',
#  'Spice - Peppercorn Melange',
#  'Bread - Hot Dog Buns',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Wine - Alsace Gewurztraminer',
#  'Wine - Vidal Icewine Magnotta',
#  'Beans - Kidney, Red Dry',
#  'Garlic - Elephant',
#  'Juice - Cranberry, 341 Ml',
#  'Water - Green Tea Refresher',
#  'Water - Spring Water 500ml',
#  'Creme De Banane - Marie',
#  'Water - Green Tea Refresher',
#  'Soup - Campbells, Lentil',
#  'Liners - Baking Cups',
#  'Pork - Loin, Center Cut',
#  'Water - Green Tea Refresher',
#  'Water - Spring Water 500ml',
#  'Spice - Peppercorn Melange',
#  'Bread - Hot Dog Buns',
#  'Juice - Cranberry, 341 Ml',
#  'Water - Green Tea Refresher',
#  'Cheese - Cambozola',
#  'Spice - Peppercorn Melange',
#  'Bread - Hot Dog Buns',
#  'Sauce - Rosee',
#  'Water - Green Tea Refresher',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Rabbit - Whole',
#  'Raspberries - Fresh',
#  'Water - Green Tea Refresher',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Remy Red',
#  'Cheese - Cambozola',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Wine - Magnotta, Merlot Sr Vqa',
#  'Bread - Hot Dog Buns',
#  'Water - Green Tea Refresher',
#  'Wine - Magnotta, Merlot Sr Vqa',
#  'Beans - Kidney, Red Dry',
#  'Tea - English Breakfast',
#  'Wine - Alsace Gewurztraminer',
#  'Cheese - Cambozola',
#  'Steam Pan - Half Size Deep',
#  'Water - Green Tea Refresher',
#  'Gatorade - Xfactor Berry',
#  'Cheese - Cambozola',
#  'Steam Pan - Half Size Deep',
#  'Cheese - Cambozola',
#  'Bread - Roll, Canadian Dinner',
#  'Wine - Magnotta, Merlot Sr Vqa',
#  'Water - Green Tea Refresher',
#  'Hinge W Undercut',
#  'Wine - Vidal Icewine Magnotta',
#  'Water - Green Tea Refresher',
#  'Cheese - Cambozola',
#  'Tea - English Breakfast',
#  'Bread - Hot Dog Buns',
#  'Water - Green Tea Refresher',
#  'Cookies Cereal Nut',
#  'Remy Red',
#  'Water - Green Tea Refresher',
#  'Pepper - Paprika, Hungarian',
#  'Bread - Hot Dog Buns',
#  'Cheese - Cambozola',
#  'Water - Green Tea Refresher',
#  'Smoked Paprika',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Cheese - Cambozola',
#  'Water - Green Tea Refresher',
#  'Pasta - Detalini, White, Fresh',
#  'Onions - Vidalia',
#  'Wine - Magnotta - Belpaese',
#  'Wine - Magnotta - Belpaese',
#  'Water - Green Tea Refresher',
#  'Bread - Hot Dog Buns',
#  'Soupfoamcont12oz 112con',
#  'Pork - Loin, Center Cut',
#  'Garlic',
#  'Water - Green Tea Refresher',
#  'Steam Pan - Half Size Deep',
#  'Bread - Hot Dog Buns',
#  'Bar - Granola Trail Mix Fruit Nut',
#  'Bread - Hot Dog Buns',
#  'Rabbit - Whole',
#  'Barramundi']

# %% [markdown]
# ### Step 4: Count the number of times each similar product occurs in your filtered list. Sort and return a list containing the top 5 items.

# %%
pd.Series(sim).value_counts()[:5]
# Out:
# Water - Green Tea Refresher          38
# Bread - Hot Dog Buns                 20
# Cheese - Cambozola                   19
# Bar - Granola Trail Mix Fruit Nut    12
# Spice - Peppercorn Melange           11
# dtype: int64

# %% [markdown]
# ### Step 5: Now that we have generated product recommendations for a single user, put the pieces together and iterate over a list of all CustomerIDs.
#
# - Create an empty dictionary that will hold the recommendations for all customers.
# - Create a list of unique CustomerIDs to iterate over.
# - Iterate over the customer list performing steps 2 through 4 for each and appending the results of each iteration to the dictionary you created.

# %%
recomended={}

for cust in data['CustomerID'].unique():
    sim=[]
    for prod in customer_products['ProductName'][customer_products['CustomerID']==cust].unique():
        for elem in distances[prod].sort_values(ascending=False)[0:5].index.to_list():
            sim.append(elem)
        if prod in sim:
            sim.remove(prod)
    recommend_temp=list(pd.Series(sim).value_counts()[:5].index)
    recomended[cust]=recommend_temp
recomended
# Out:
# {61288: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Raspberries - Fresh',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  77352: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  40094: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Beans - Kidney, Red Dry'],
#  23548: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep'],
#  78981: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Wine - Alsace Gewurztraminer',
#   'Sauce - Hollandaise'],
#  83106: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Spice - Peppercorn Melange'],
#  11253: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise'],
#  35107: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Rosee',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  15088: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  26031: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Wine - Alsace Gewurztraminer',
#   'Rabbit - Whole',
#   'Sauce - Hollandaise'],
#  86595: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Steam Pan - Half Size Deep'],
#  46715: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep'],
#  91013: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola'],
#  69931: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Sauce - Rosee',
#   'Raspberries - Fresh'],
#  19753: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  9546: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Hollandaise'],
#  10224: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  72846: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Wine - Alsace Gewurztraminer'],
#  28976: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Hollandaise'],
#  3267: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Beans - Kidney, Red Dry'],
#  19260: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  76530: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep'],
#  30196: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Beans - Kidney, Red Dry',
#   'Cheese - Cambozola'],
#  48818: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Scallops 60/80 Iqf'],
#  15166: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise'],
#  11443: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise'],
#  79060: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  82597: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Scallops 60/80 Iqf'],
#  62411: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Sauce - Rosee'],
#  42611: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Scallops 60/80 Iqf'],
#  45420: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Sauce - Rosee'],
#  83495: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Rosee'],
#  47122: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Rabbit - Whole',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  30815: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  53198: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Sauce - Rosee'],
#  18591: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Rosee'],
#  62034: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Hollandaise'],
#  1428: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Rabbit - Whole',
#   'Sauce - Hollandaise'],
#  2187: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola',
#   'Rabbit - Whole'],
#  55162: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Rabbit - Whole'],
#  22345: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep'],
#  81876: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Rosee',
#   'Rabbit - Whole'],
#  48641: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Spice - Peppercorn Melange'],
#  81034: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise'],
#  29681: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  87947: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep'],
#  28867: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  69967: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  94420: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  83158: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Rosee',
#   'Steam Pan - Half Size Deep'],
#  84364: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bread - Hot Dog Buns',
#   'Sauce - Rosee',
#   'Sauce - Hollandaise'],
#  44742: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  7772: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  47303: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise'],
#  75791: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Rosee'],
#  77756: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Sauce - Rosee'],
#  97324: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise'],
#  13912: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola'],
#  52700: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Rabbit - Whole'],
#  21734: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  6817: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Rabbit - Whole'],
#  21095: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Wine - Alsace Gewurztraminer'],
#  28875: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Wine - Alsace Gewurztraminer'],
#  89588: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Rabbit - Whole',
#   'Scallops 60/80 Iqf'],
#  1034: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola'],
#  54827: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola'],
#  29287: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep'],
#  11102: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Sauce - Rosee'],
#  52155: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Scallops 60/80 Iqf'],
#  50748: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  88552: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bread - Hot Dog Buns',
#   'Hinge W Undercut',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  80938: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Rabbit - Whole',
#   'Wine - Alsace Gewurztraminer'],
#  60481: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise'],
#  92168: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  66232: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Sauce - Rosee',
#   'Steam Pan - Half Size Deep'],
#  64348: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Wine - Alsace Gewurztraminer'],
#  37510: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Scallops 60/80 Iqf',
#   'Sauce - Hollandaise'],
#  44408: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise'],
#  89254: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  477: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  51483: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Hollandaise',
#   'Wine - Alsace Gewurztraminer'],
#  97201: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  42157: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Rabbit - Whole',
#   'Sauce - Hollandaise'],
#  52091: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep'],
#  86065: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Wine - Alsace Gewurztraminer',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  18027: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Rosee',
#   'Hinge W Undercut'],
#  93882: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Rosee',
#   'Cheese - Cambozola',
#   'Spice - Peppercorn Melange'],
#  42303: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  32010: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Scallops 60/80 Iqf',
#   'Sauce - Hollandaise'],
#  53997: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Milk Powder'],
#  63033: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Sauce - Rosee'],
#  76475: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  98185: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise'],
#  84779: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Rabbit - Whole'],
#  82146: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Rabbit - Whole'],
#  54495: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise'],
#  3903: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Sauce - Rosee'],
#  79854: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  25449: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Rabbit - Whole',
#   'Cheese - Cambozola'],
#  85496: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise'],
#  95017: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola'],
#  33759: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Spice - Peppercorn Melange'],
#  43652: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Hinge W Undercut',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola'],
#  35873: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  97769: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Wine - Alsace Gewurztraminer',
#   'Sauce - Hollandaise'],
#  891: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  85161: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Rabbit - Whole',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise'],
#  25327: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  25624: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  68416: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  44090: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola'],
#  71595: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise'],
#  68336: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Steam Pan - Half Size Deep'],
#  38497: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Rabbit - Whole',
#   'Sauce - Rosee'],
#  10016: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Rabbit - Whole'],
#  36751: ['Bread - Hot Dog Buns',
#   'Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Spice - Peppercorn Melange'],
#  58421: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bread - Hot Dog Buns',
#   'Wine - Alsace Gewurztraminer',
#   'Sauce - Hollandaise'],
#  45498: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Rosee',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  50774: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola'],
#  79997: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola',
#   'Sauce - Rosee'],
#  45313: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  55715: ['Water - Green Tea Refresher',
#   'Sauce - Hollandaise',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola'],
#  40901: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola'],
#  1577: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  3909: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Rosee',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola'],
#  18480: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Scallops 60/80 Iqf'],
#  41405: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise'],
#  85552: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola'],
#  412: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Wine - Alsace Gewurztraminer',
#   'Spice - Peppercorn Melange'],
#  59399: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Rabbit - Whole',
#   'Steam Pan - Half Size Deep'],
#  87849: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise'],
#  26458: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Rosee'],
#  13354: ['Water - Green Tea Refresher',
#   'Sauce - Hollandaise',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola'],
#  92673: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Sauce - Rosee',
#   'Wine - Alsace Gewurztraminer'],
#  45759: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola',
#   'Wine - Alsace Gewurztraminer'],
#  55930: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Rosee'],
#  62184: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise'],
#  70512: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola'],
#  51451: ['Water - Green Tea Refresher',
#   'Steam Pan - Half Size Deep',
#   'Bread - Hot Dog Buns',
#   'Scallops 60/80 Iqf',
#   'Cheese - Cambozola'],
#  46046: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Hollandaise'],
#  1754: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Wine - Alsace Gewurztraminer'],
#  2915: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Sauce - Rosee'],
#  81591: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Wine - Alsace Gewurztraminer',
#   'Sauce - Hollandaise'],
#  78104: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise'],
#  81179: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Rosee'],
#  9047: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  85292: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Sauce - Rosee'],
#  95819: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola'],
#  74237: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Rabbit - Whole',
#   'Sauce - Rosee'],
#  264: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola',
#   'Beans - Kidney, Red Dry'],
#  49159: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Rosee',
#   'Raspberries - Fresh',
#   'Cheese - Cambozola'],
#  81845: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola'],
#  4644: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bread - Hot Dog Buns',
#   'Wine - Alsace Gewurztraminer',
#   'Sauce - Hollandaise'],
#  41538: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola'],
#  40863: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  60759: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola'],
#  17760: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Raspberries - Fresh'],
#  2776: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep'],
#  42802: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Spice - Peppercorn Melange'],
#  26353: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Hollandaise'],
#  25420: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Raspberries - Fresh'],
#  98200: ['Water - Green Tea Refresher',
#   'Cheese - Cambozola',
#   'Rabbit - Whole',
#   'Bread - Hot Dog Buns',
#   'Sauce - Rosee'],
#  69027: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Rosee'],
#  87030: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Steam Pan - Half Size Deep'],
#  27669: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  82432: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Rosee'],
#  20331: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Rosee',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  75022: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Rabbit - Whole'],
#  14012: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Sauce - Hollandaise'],
#  10418: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Steam Pan - Half Size Deep',
#   'Cheese - Cambozola',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  24271: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep'],
#  86662: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Cheese - Cambozola'],
#  22461: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Scallops 60/80 Iqf',
#   'Bar - Granola Trail Mix Fruit Nut'],
#  78054: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Sauce - Hollandaise',
#   'Wine - Alsace Gewurztraminer'],
#  81715: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Cheese - Cambozola',
#   'Steam Pan - Half Size Deep',
#   'Sauce - Hollandaise'],
#  65757: ['Water - Green Tea Refresher',
#   'Bread - Hot Dog Buns',
#   'Sauce - Hollandaise',
#   'Cheese - Cambozola',
#   '
# 0        Water - Green Tea Refresher  Water - Green Tea Refresher
# 1               Bread - Hot Dog Buns         Bread - Hot Dog Buns
# 2                Sauce - Hollandaise           Cheese - Cambozola
# 3  Bar - Granola Trail Mix Fruit Nut          Sauce - Hollandaise
# 4                 Cheese - Cambozola   Steam Pan - Half Size Deep
#
#                                74403                              49005  \
# 0        Water - Green Tea Refresher        Water - Green Tea Refresher
# 1               Bread - Hot Dog Buns               Bread - Hot Dog Buns
# 2                 Cheese - Cambozola                 Cheese - Cambozola
# 3  Bar - Granola Trail Mix Fruit Nut                      Sauce - Rosee
# 4                      Sauce - Rosee  Bar - Granola Trail Mix Fruit Nut
#
#                                41286                              85878  \
# 0        Water - Green Tea Refresher        Water - Green Tea Refresher
# 1               Bread - Hot Dog Buns               Bread - Hot Dog Buns
# 2                 Cheese - Cambozola  Bar - Granola Trail Mix Fruit Nut
# 3                      Sauce - Rosee       Wine - Alsace Gewurztraminer
# 4  Bar - Granola Trail Mix Fruit Nut                Sauce - Hollandaise
#
#                           68506                         3472
# 0   Water - Green Tea Refresher   Water - Green Tea Refresher
# 1            Cheese - Cambozola          Bread - Hot Dog Buns
# 2    Steam Pan - Half Size Deep            Cheese - Cambozola
# 3          Bread - Hot Dog Buns           Sauce - Hollandaise
# 4  Wine - Alsace Gewurztraminer  Wine - Alsace Gewurztraminer
#
# [5 rows x 1000 columns]

# %% [markdown]
# ## Recommending Items to a New Customer
#
# Suppose we get a new customer and on their first visit, they purchase the following items and quantities.

# %%
new_customer = {'Cookies - Assorted':3,
                'Flavouring - Orange':3,
                'Fenngreek Seed':1,
                'Wine - White Cab Sauv.on':1,
                'Bandage - Flexible Neon':3,
                'Oil - Shortening - All - Purpose':2,
                'Beef - Montreal Smoked Brisket':4,
                'French Pastry - Mini Chocolate':4,
                'Snapple Lemon Tea':5,
                'Pepper - White, Ground':2,
                'Spinach - Baby':5,
                'Sole - Dover, Whole, Fresh':4}

# %% [markdown]
# ### Step 7: Recommend 5 products to this new customer using a user similarity approach.

# %%
customer_products = customer_products.append([pd.Series([1,product,quantity], index=customer_products.columns) for (product,quantity) in new_customer.items()], ignore_index=True)
data_by_CustomerID_Product=customer_products.groupby(by=['CustomerID','ProductName'])['Quantity'].sum()
Pivot_Table=pd.pivot_table(customer_products,values='Quantity',index='ProductName',columns='CustomerID',aggfunc='sum').fillna(0)
distances = pd.DataFrame(1/(1 + squareform(pdist(Pivot_Table.T, 'euclidean'))),index=Pivot_Table.columns, columns=Pivot_Table.columns)
similarities = distances[1].sort_values(ascending=False)[1:]
Clientes = data_by_CustomerID_Product.loc[list(similarities.index)]
Order_sim_quantity=Clientes.groupby(by=['ProductName']).sum().sort_values(ascending=False)
merging=Pivot_Table.merge(Order_sim_quantity,on='ProductName')
recomended_products = merging[merging[1]==0].nlargest(5,'Quantity')['Quantity']
recomended_products
#cust_prod_pivot = cust_prod_pivot.div(cust_prod_pivot.sum(axis=1), axis=0)
#cust_dist = pd.DataFrame(1/(1 + squareform(pdist(cust_prod_pivot, 'euclidean'))),
#                       index=cust_prod_pivot.index, columns=cust_prod_pivot.index)
# Out:
# ProductName
# Wine - White, Mosel Gold       2306
# Tea - Jasmin Green             2305
# Kiwi                           2304
# Cheese - Brie,danish           2283
# Soup Knorr Chili With Beans    2276
# Name: Quantity, dtype: int64

# %% [markdown]
# ### Step 8: Recommend 5 products to this new customer using a item similarity approach.

# %%
distances = pd.DataFrame(1/(1 + squareform(pdist(cust_prod_pivot.T, 'euclidean'))),index=cust_prod_pivot.columns, columns=cust_prod_pivot.columns)
prod_purchase=customer_products['ProductName'][customer_products['CustomerID']==1].unique()
prod_cust_pivot = customer_products.pivot_table(values='Quantity', 
                                                columns='CustomerID', 
                                                index='ProductName', 
                                                aggfunc='sum').fillna(0)


cust_prod_pivot = prod_cust_pivot.T

sim=[]

for prod in prod_purchase:
    for elem  in distances[prod].sort_values(ascending=False)[1:6].index.to_list():
        sim.append(elem)
        
sim

for prod in prod_purchase:
    if prod in sim:
        sim.remove(prod)
sim

pd.Series(sim).value_counts()[:5]
# Out:
# Scallops 60/80 Iqf             6
# Water - Green Tea Refresher    5
# Rabbit - Whole                 3
# Pork - Loin, Center Cut        3
# Raspberries - Fresh            3
# dtype: int64
